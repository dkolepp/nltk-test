# %% [markdown]
# # SpaCy Stuff

# %%
import spacy
import nltk
from pprint import pprint

nlp = spacy.load('en_core_web_sm')


GLS_text_here='''
The use of containers not only helps with the efficiency, elasticity, and reusability of the hosted applications, but also with application portability.
The Open Container Initiative provides a set of industry standards that define a container runtime specification and a container image specification.
The image specification defines the format for the bundle of files and metadata that form a container image.
When you build an application as a container image, which complies with the OCI standard, you can use any OCI-compliant container engine to execute the application.
'''

GLS_text_here='''
To retrieve the project files for an existing software project with Git, you clone the Git repository for the project.

When you clone a project, a complete copy of the original remote repository is created locally on your system. Your local copy of the repository contains the entire history of the project files, not just the latest version of project files. You can switch to different versions of the application, or compare two different versions of a file, without connecting to the remote repository. This allows you to continue implementing code changes when the remote repository is not available.

Git does not automatically synchronize local repository changes to the remote repository, nor does it automatically download new remote changes to your local copy of the repository. You control when Git downloads commits from the remote repository, and when local commits are uploaded to the remote repository. Git provides several mechanisms to safely synchronize your local repository with the remote project repository.

To track file changes in Git, you create a series of project snapshots as you make changes to your project. Each snapshot is called a commit. When you commit code changes to your repository, you create a new code snapshot in your Git repository.
'''
sentences = nltk.sent_tokenize(GLS_text_here)

# %%
doc = nlp(GLS_text_here)
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# To retrieve the project files for an existing software project with Git, you clone the Git repository for the project.
#
# When you clone a project, a complete copy of the original remote repository is created locally on your system. Your local copy of the repository contains the entire history of the project files, not just the latest version of project files. You can switch to different versions of the application, or compare two different versions of a file, without connecting to the remote repository. This allows you to continue implementing code changes when the remote repository is not available.
#
# Git does not automatically synchronize local repository changes to the remote repository, nor does it automatically download new remote changes to your local copy of the repository. You control when Git downloads commits from the remote repository, and when local commits are uploaded to the remote repository. Git provides several mechanisms to safely synchronize your local repository with the remote project repository.
#
# To track file changes in Git, you create a series of project snapshots as you make changes to your project. Each snapshot is called a commit. When you commit code changes to your repository, you create a new code snapshot in your Git repository.
#
#
#  SPACE
# To PART aux
# retrieve VERB advcl
# the DET det
# project NOUN compound
# files NOUN dobj
# for ADP prep
# an DET det
# existing VERB amod
# software NOUN compound
# project NOUN pobj
# with ADP prep
# Git PROPN pobj
# , PUNCT punct
# you PRON nsubj
# clone VERB ROOT
# the DET det
# Git PROPN compound
# repository NOUN dobj
# for ADP prep
# the DET det
# project NOUN pobj
# . PUNCT punct
#
#
#  SPACE
# When ADV advmod
# you PRON nsubj
# clone VERB advcl
# a DET det
# project NOUN dobj
# , PUNCT punct
# a DET det
# complete ADJ amod
# copy NOUN nsubjpass
# of ADP prep
# the DET det
# original ADJ amod
# remote ADJ amod
# repository NOUN pobj
# is AUX auxpass
# created VERB ROOT
# locally ADV advmod
# on ADP prep
# your PRON poss
# system NOUN pobj
# . PUNCT punct
# Your PRON poss
# local ADJ amod
# copy NOUN nsubj
# of ADP prep
# the DET det
# repository NOUN pobj
# contains VERB ROOT
# the DET det
# entire ADJ amod
# history NOUN dobj
# of ADP prep
# the DET det
# project NOUN compound
# files NOUN pobj
# , PUNCT punct
# not PART neg
# just ADV advmod
# the DET det
# latest ADJ amod
# version NOUN appos
# of ADP prep
# project NOUN compound
# files NOUN pobj
# . PUNCT punct
# You PRON nsubj
# can AUX aux
# switch VERB ROOT
# to ADP prep
# different ADJ amod
# versions NOUN pobj
# of ADP prep
# the DET det
# application NOUN pobj
# , PUNCT punct
# or CCONJ cc
# compare VERB conj
# two NUM nummod
# different ADJ amod
# versions NOUN dobj
# of ADP prep
# a DET det
# file NOUN pobj
# , PUNCT punct
# without ADP prep
# connecting VERB pcomp
# to ADP prep
# the DET det
# remote ADJ amod
# repository NOUN pobj
# . PUNCT punct
# This DET nsubj
# allows VERB ROOT
# you PRON nsubj
# to PART aux
# continue VERB ccomp
# implementing VERB xcomp
# code NOUN compound
# changes NOUN dobj
# when ADV advmod
# the DET det
# remote ADJ amod
# repository NOUN nsubj
# is AUX advcl
# not PART neg
# available ADJ acomp
# . PUNCT punct
#
#
#  SPACE
# Git PROPN nsubj
# does AUX aux
# not PART neg
# automatically ADV advmod
# synchronize VERB ROOT
# local ADJ amod
# repository NOUN amod
# changes NOUN dobj
# to ADP prep
# the DET det
# remote ADJ amod
# repository NOUN pobj
# , PUNCT punct
# nor CCONJ cc
# does AUX aux
# it PRON nsubj
# automatically ADV advmod
# download VERB conj
# new ADJ amod
# remote ADJ amod
# changes NOUN dobj
# to ADP prep
# your PRON poss
# local ADJ amod
# copy NOUN pobj
# of ADP prep
# the DET det
# repository NOUN pobj
# . PUNCT punct
# You PRON nsubj
# control VERB ROOT
# when ADV advmod
# Git PROPN nsubj
# downloads VERB advcl
# commits NOUN dobj
# from ADP prep
# the DET det
# remote ADJ amod
# repository NOUN pobj
# , PUNCT punct
# and CCONJ cc
# when ADV advmod
# local ADJ amod
# commits NOUN nsubjpass
# are AUX auxpass
# uploaded ADJ conj
# to ADP prep
# the DET det
# remote ADJ amod
# repository NOUN pobj
# . PUNCT punct
# Git PROPN nsubj
# provides VERB ROOT
# several ADJ amod
# mechanisms NOUN dobj
# to PART aux
# safely ADV advmod
# synchronize VERB xcomp
# your PRON poss
# local ADJ amod
# repository NOUN dobj
# with ADP prep
# the DET det
# remote ADJ amod
# project NOUN compound
# repository NOUN pobj
# . PUNCT punct
#
#
#  SPACE
# To PART aux
# track VERB advcl
# file NOUN compound
# changes NOUN dobj
# in ADP prep
# Git PROPN pobj
# , PUNCT punct
# you PRON nsubj
# create VERB ROOT
# a DET det
# series NOUN dobj
# of ADP prep
# project NOUN compound
# snapshots NOUN pobj
# as SCONJ mark
# you PRON nsubj
# make VERB advcl
# changes NOUN dobj
# to ADP prep
# your PRON poss
# project NOUN pobj
# . PUNCT punct
# Each DET det
# snapshot NOUN nsubjpass
# is AUX auxpass
# called VERB ROOT
# a DET det
# commit NOUN oprd
# . PUNCT punct
# When ADV advmod
# you PRON nsubj
# commit VERB advcl
# code NOUN compound
# changes NOUN dobj
# to ADP prep
# your PRON poss
# repository NOUN pobj
# , PUNCT punct
# you PRON nsubj
# create VERB ROOT
# a DET det
# new ADJ amod
# code NOUN compound
# snapshot NOUN dobj
# in ADP prep
# your PRON poss
# Git PROPN compound
# repository NOUN pobj
# . PUNCT punct
#
#  SPACE

# %% [markdown]
# Display the syntax dependency:

# %%
spacy.displacy.render(doc, style="dep")
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a1b8ba274c1a4103a245de0085e17269-0" class="displacy" width="36800" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">To</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">retrieve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">project</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">files</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">existing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">software</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">project</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Git,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">clone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Git</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">repository</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">project.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">When</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">clone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">project,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">complete</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">copy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="

# %% [markdown]
# # Named Entity Recognition

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Git 69 72 PERSON
# two 430 433 CARDINAL
# Git 920 923 PERSON
# Git 1058 1061 GPE

# %%
spacy.displacy.render(doc, style="ent")
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr"></br>To retrieve the project files for an existing software project with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Git
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , you clone the Git repository for the project.</br></br>When you clone a project, a complete copy of the original remote repository is created locally on your system. Your local copy of the repository contains the entire history of the project files, not just the latest version of project files. You can switch to different versions of the application, or compare
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  different versions of a file, without connecting to the remote repository. This allows you to continue implementing code changes when the remote repository is not available.</br></br>Git does not automatically synchronize local repository changes to the remote repository, nor does it automatically download new remote changes to your local copy of the repository. You control when Git downloads commits from the remote repository, and when local commits are uploaded to the remote repository.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Git
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  provides several mechanisms to safely synchronize your local repository with the remote project repository.</br></br>To track file changes in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Git
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , you create a series of project snapshots as you make changes to your project. Each snapshot is called a commit. When you commit code changes to your repository, you create a new code snapshot in your Git repository.
# </div>

# %%
import plac
import random
from pathlib import Path
import spacy
from spacy.util import minibatch, compounding

# %%
nlp2 = spacy.blank("en")

# %%
print(dir(nlp2))
# Out:
# ['Defaults', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_format_docs_and_golds', '_meta', '_multiprocessing_pipe', '_optimizer', '_path', 'add_pipe', 'begin_training', 'create_pipe', 'disable_pipes', 'entity', 'evaluate', 'factories', 'from_bytes', 'from_disk', 'get_pipe', 'has_pipe', 'lang', 'linker', 'make_doc', 'matcher', 'max_length', 'meta', 'parser', 'path', 'pipe', 'pipe_factories', 'pipe_labels', 'pipe_names', 'pipeline', 'preprocess_gold', 'rehearse', 'remove_pipe', 'rename_pipe', 'replace_pipe', 'resume_training', 'tagger', 'tensorizer', 'to_bytes', 'to_disk', 'tokenizer', 'update', 'use_params', 'vocab']
